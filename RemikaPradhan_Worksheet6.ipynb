# %% [markdown]
# Student Name : Remika Pradhan
#
# Student Number : 2408260

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Ai and Ml/Copy of FruitinAmazon.zip"
extract_path = "dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction completed successfully")
# Out:
# Extraction completed successfully

# %% [markdown]
# # Identifying dataset classes

# %%
train_dir = "dataset/FruitinAmazon/train"

#getting the class name/subdirectories
class_names = sorted(os.listdir(train_dir))

print("Dataset name: ",os.listdir("dataset"))

if not class_names:
  print("No class directories foiunf in the train folder!!")
else:
  print("Class names:",class_names)
# Out:
# Dataset name:  ['FruitinAmazon']
# Class names: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# # Visualizing sample images

# %%
import random
import matplotlib.pyplot as plt
from PIL import Image

classes = sorted(os.listdir(train_dir))

plt.figure(figsize=(6,6))
#this is to display one random image from each class
for i, cls in enumerate(classes):
    class_path = os.path.join(train_dir, cls)
    img_name = random.choice(os.listdir(class_path))
    img_path = os.path.join(class_path, img_name)

    img = Image.open(img_path)

    plt.subplot(2, (len(classes)//2)+1, i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")

plt.show()

# %% [markdown]
# The dataset contains images grouped into class folders. Each folder represents a fruit category. The images vary in orientation, lighting, and background but share common visual features that help the CNN learn patterns.

# %%
from PIL import Image,UnidentifiedImageError

corrupted_images = [] #list to store all the corrupted images
#looping through each class folder and cheking for the corrupted images
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir,class_name)
    if os.path.isdir(class_path):  #ensuring it is a valid directory
      images = os.listdir(class_path)
      for file in os.listdir(class_path):
        image_path = os.path.join(class_path,file)
        try:
            with Image.open(image_path) as img:
              img.verify() #verifying if image can be opened correctly

        except (IOError, UnidentifiedImageError):

                corrupted_images.append(image_path)
                os.remove(image_path)
                print(f"Removed corrupted image: {image_path}")

if corrupted_images:
    print("Corrupted images found:")
    for img in corrupted_images:
        print(img)
else:
  print("No corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# # Checking class imbalance

# %%
#dictionary to store the number of images in each class
class_counts = {}

for class_name in class_names:
  class_path = os.path.join(train_dir, class_name)
  if os.path.isdir(class_path):
    images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png','.jpg','jpeg'))]
    class_counts[class_name] = len(images) #counts images in each class

#printing class imbalance
print("\nClass Distribution:")
print("=" * 45)
print(f"{'Class Name':<25}{'Valid image count':>15}")
print("=" * 45)
for class_name, count in class_counts.items():
    print(f"{class_name:<25}{count:>15}")
print("="* 45)
# Out:
# Class Distribution:
# =============================================
# Class Name               Valid image count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================

# %% [markdown]
# # Random Image Selection

# %%
import random
selected_images = [] # Store image paths
selected_labels = [] # Store corresponding class names
for class_name in class_names:
  class_path = os.path.join(train_dir, class_name)
  if os.path.isdir(class_path):
    images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if images: # Ensure the class folder is not empty
      selected_img = os.path.join(class_path, random.choice(images))
      selected_images.append(selected_img)
      selected_labels.append(class_name)

# %% [markdown]
# # Random image Plot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Determine grid size
num_classes = len(selected_images)
cols = (num_classes + 1) // 2 # Determine columns
rows = 2 # Fixed rows for layout
fig, axes = plt.subplots(rows, cols, figsize=(6, 6))
for i, ax in enumerate(axes.flat):
  if i < num_classes:
    img = mpimg.imread(selected_images[i])
    ax.imshow(img)
    ax.set_title(selected_labels[i])
    ax.axis("off")
  else:
    ax.axis("off") # Hide empty subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data loading and preprocessing

# %%
import tensorflow as tf

img_height = 224
img_width = 224
batch_size = 32
validation_split = 0.2
#normalizing pixel values from 0-255 to 0-1
rescale = tf.keras.layers.Rescaling(1./255)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height,img_width),
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)
#loading validation dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height,img_width),
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)
#applying normalization to datasets
train_ds = train_ds.map(lambda x,y:(rescale(x),y))
val_ds = val_ds.map(lambda x,y:(rescale(x),y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
]

def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %% [markdown]
# # CNN model Task 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Dense, Flatten
from tensorflow.keras import layers

model = Sequential([

    # Data augmentation
    layers.Lambda(data_augmentation, input_shape=(224,224,3)),

    # Block 1
    Conv2D(32, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    # Block 2
    Conv2D(64, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    # Block 3
    Conv2D(128, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    # Block 4
    Conv2D(256, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    # Flatten
    Flatten(),

    # Fully connected layer
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    # Output layer
    Dense(len(class_names), activation='softmax')
])

# %%
model.compile(
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda_2 (Lambda)               │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │     6,422,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,814,278 (25.99 MB)
#  Trainable params: 6,813,062 (25.99 MB)
#  Non-trainable params: 1,216 (4.75 KB)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Save the best model during training
checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Stop training if validation loss does not improve
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2072 - loss: 2.8107
# Epoch 1: val_loss improved from None to 1.75488, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 27s 7s/step - accuracy: 0.2778 - loss: 2.5042 - val_accuracy: 0.1111 - val_loss: 1.7549
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6105 - loss: 1.3200
# Epoch 2: val_loss improved from 1.75488 to 1.48448, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.5972 - loss: 1.3474 - val_accuracy: 0.4444 - val_loss: 1.4845
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5503 - loss: 1.1950
# Epoch 3: val_loss improved from 1.48448 to 1.14412, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.5417 - loss: 1.2082 - val_accuracy: 0.5000 - val_loss: 1.1441
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6458 - loss: 0.9282
# Epoch 4: val_loss improved from 1.14412 to 1.04411, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 6s/step - accuracy: 0.6250 - loss: 1.0028 - val_accuracy: 0.5556 - val_loss: 1.0441
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5249 - loss: 1.1250
# Epoch 5: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.5278 - loss: 1.1025 - val_accuracy: 0.8333 - val_loss: 1.0766
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7118 - loss: 0.8639
# Epoch 6: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 6s/step - accuracy: 0.6667 - loss: 0.9452 - val_accuracy: 0.8333 - val_loss: 1.3483
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6644 - loss: 0.8369
# Epoch 7: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 0.6806 - loss: 0.8427 - val_accuracy: 0.6667 - val_loss: 1.5225
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7604 - loss: 0.7016
# Epoch 8: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 6s/step - accuracy: 0.7500 - loss: 0.7628 - val_accuracy: 0.3333 - val_loss: 1.7886
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7546 - loss: 0.6237
# Epoch 9: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 0.7639 - loss: 0.6041 - val_accuracy: 0.0000e+00 - val_loss: 2.2605
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7095 - loss: 0.9661
# Epoch 10: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 7s/step - accuracy: 0.7222 - loss: 0.8882 - val_accuracy: 0.0556 - val_loss: 1.9610
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.6800 - loss: 0.8524
# Epoch 11: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.6806 - loss: 0.8599 - val_accuracy: 0.1111 - val_loss: 2.3772
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.8160 - loss: 0.5464
# Epoch 12: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.7917 - loss: 0.5846 - val_accuracy: 0.1111 - val_loss: 3.7724
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.7350 - loss: 0.7187
# Epoch 13: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step - accuracy: 0.7361 - loss: 0.7131 - val_accuracy: 0.1667 - val_loss: 3.9906
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7610 - loss: 0.6312
# Epoch 14: val_loss did not improve from 1.04411
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 0.7361 - loss: 0.6981 - val_accuracy: 0.1111 - val_loss: 3.8141
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
plt.plot(history.history['accuracy'],label='train')
plt.plot(history.history['val_accuracy'],label='validation')

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()


plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
test_loss,test_acc = model.evaluate(val_ds)

print("Test Accuracy:",test_acc)
print("Test Loss:",test_loss)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5556 - loss: 1.0441
# Test Accuracy: 0.5555555820465088
# Test Loss: 1.0441079139709473

# %%
# Save the trained model
model.save("fruit_cnn_model.keras")

# Load the saved model
from tensorflow.keras.models import load_model
loaded_model = load_model("fruit_cnn_model.keras")

# Evaluate the loaded model
loss, accuracy = loaded_model.evaluate(val_ds)

print("Loaded Model Accuracy:", accuracy)
print("Loaded Model Loss:", loss)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 24 variables whereas the saved optimizer has 46 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5556 - loss: 1.0441
# Loaded Model Accuracy: 0.5555555820465088
# Loaded Model Loss: 1.0441079139709473

# %%
import numpy as np
from sklearn.metrics import classification_report

y_true = []
y_pred = []

for images,labels in val_ds:

    predictions = loaded_model.predict(images)

    pred_labels = np.argmax(predictions,axis=1)

    y_true.extend(labels.numpy())
    y_pred.extend(pred_labels)
unique_labels = np.unique(y_true)

print(classification_report(y_true,y_pred, labels=unique_labels,target_names=[classes[i] for i in unique_labels]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 792ms/step
#               precision    recall  f1-score   support
#
#      pupunha       0.00      0.00      0.00         3
#       tucuma       0.77      0.67      0.71        15
#
#    micro avg       0.77      0.56      0.65        18
#    macro avg       0.38      0.33      0.36        18
# weighted avg       0.64      0.56      0.60        18
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Transfer Learning (VGG16)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %% [markdown]
# # Load Pretrained VGG16 Model

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %% [markdown]
# # Freeze pretrained layers

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# # Build Transfer Learning Model

# %%
model_transfer = Sequential([

    base_model,

    Flatten(),

    Dense(256, activation='relu'),

    Dense(len(class_names), activation='softmax')
])

# %% [markdown]
# # Compile the Model

# %%
model_transfer.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Train the Model

# %%
history_transfer = model_transfer.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15
)
# Out:
# Epoch 1/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.1146 - loss: 5.0172
# WARNING:tensorflow:5 out of the last 60 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x79064a42a200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 74s 23s/step - accuracy: 0.1250 - loss: 6.7558 - val_accuracy: 0.8333 - val_loss: 1.2624
# Epoch 2/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 90s 24s/step - accuracy: 0.3333 - loss: 5.8653 - val_accuracy: 0.3333 - val_loss: 2.2926
# Epoch 3/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 61s 19s/step - accuracy: 0.6806 - loss: 1.0686 - val_accuracy: 0.4444 - val_loss: 1.6197
# Epoch 4/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 61s 19s/step - accuracy: 0.6944 - loss: 0.7151 - val_accuracy: 0.7778 - val_loss: 0.5594
# Epoch 5/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 81s 20s/step - accuracy: 0.9444 - loss: 0.2604 - val_accuracy: 0.9444 - val_loss: 0.2002
# Epoch 6/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 58s 19s/step - accuracy: 0.9722 - loss: 0.1576 - val_accuracy: 0.9444 - val_loss: 0.1299
# Epoch 7/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 60s 20s/step - accuracy: 1.0000 - loss: 0.0686 - val_accuracy: 1.0000 - val_loss: 0.0880
# Epoch 8/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 57s 19s/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0944
# Epoch 9/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 68s 23s/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9444 - val_loss: 0.1246
# Epoch 10/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 68s 23s/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9444 - val_loss: 0.1582
# Epoch 11/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 60s 19s/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9444 - val_loss: 0.1836
# Epoch 12/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 58s 19s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9444 - val_loss: 0.2019
# Epoch 13/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 84s 19s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9444 - val_loss: 0.2157
# Epoch 14/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 81s 18s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9444 - val_loss: 0.2273
# Epoch 15/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 61s 20s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9444 - val_loss: 0.2370

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

# Accuracy graph
plt.subplot(1,2,1)
plt.plot(history_transfer.history['accuracy'], label='Training Accuracy')
plt.plot(history_transfer.history['val_accuracy'], label='Validation Accuracy')
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# Loss graph
plt.subplot(1,2,2)
plt.plot(history_transfer.history['loss'], label='Training Loss')
plt.plot(history_transfer.history['val_loss'], label='Validation Loss')
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluate the Model

# %%
loss, accuracy = model_transfer.evaluate(val_ds)

print("Transfer Learning Accuracy:", accuracy)
print("Transfer Learning Loss:", loss)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.9444 - loss: 0.2370
# Transfer Learning Accuracy: 0.9444444179534912
# Transfer Learning Loss: 0.2369576245546341

# %% [markdown]
# # Fine-Tuning

# %%
base_model.trainable = True

for layer in base_model.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# # Recompile with smaller learning rate

# %%
from tensorflow.keras.optimizers import RMSprop

model_transfer.compile(
    optimizer=RMSprop(learning_rate=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Train Fine-Tuned Model

# %%
history_finetune = model_transfer.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 62s 20s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9444 - val_loss: 0.2337
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 19s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9444 - val_loss: 0.2318
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 60s 19s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9444 - val_loss: 0.2288
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 57s 18s/step - accuracy: 1.0000 - loss: 9.9505e-04 - val_accuracy: 0.9444 - val_loss: 0.2270
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 61s 20s/step - accuracy: 1.0000 - loss: 9.7156e-04 - val_accuracy: 0.9444 - val_loss: 0.2255
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 57s 18s/step - accuracy: 1.0000 - loss: 9.5258e-04 - val_accuracy: 0.9444 - val_loss: 0.2236
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 19s/step - accuracy: 1.0000 - loss: 9.2995e-04 - val_accuracy: 0.9444 - val_loss: 0.2230
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 57s 18s/step - accuracy: 1.0000 - loss: 9.1457e-04 - val_accuracy: 0.9444 - val_loss: 0.2205
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 68s 23s/step - accuracy: 1.0000 - loss: 8.9878e-04 - val_accuracy: 0.9444 - val_loss: 0.2187
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 19s/step - accuracy: 1.0000 - loss: 8.7874e-04 - val_accuracy: 0.9444 - val_loss: 0.2181

# %% [markdown]
# # Final Evaluation

# %%
loss, accuracy = model_transfer.evaluate(val_ds)

print("Fine-Tuned Model Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.9444 - loss: 0.2181
# Fine-Tuned Model Accuracy: 0.9444444179534912
